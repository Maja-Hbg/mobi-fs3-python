# %%
for x in range(1, 101):
    if x % 12 == 0:
        print(x)
# Out:
# 12
# 24
# 36
# 48
# 60
# 72
# 84
# 96

# %%
for x in range(1,13):
    if 12%x == 0:
        print(x)
# Out:
# 1
# 2
# 3
# 4
# 6
# 12
